# %%
# Models to try
# 1. Random Forest Classifier
# 2. LightGBM Classifier
# 3. XGBoost Classifier
# 4. Decision Tree
# 5. KNN
# 6. Gradient Boosting
# 7. Naive Bayes
# 8. Support Vector Classifier
# 9. MLP Classifier Sklearn


import pandas as pd
import numpy as np
from time import time
from sklearn.model_selection import cross_validate, LeaveOneOut
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, make_scorer, precision_score, recall_score, f1_score
# Models
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier



import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_is_fitted

class BaselineModel(BaseEstimator, ClassifierMixin):
    def fit(self, X, y):
        y = np.ravel(y)
        self.majority_class_ = np.bincount(y).argmax()
        return self

    def predict(self, X):
        check_is_fitted(self, 'majority_class_')
        return np.full(shape=(X.shape[0],), fill_value=self.majority_class_)

# %%
# Train and test data
approaches = {'Initial': ['real_data', 'synth_data'], 'Extra': ['real_data', 'real_pseudoreal_data', 'real_pseudoreal_synth_data']}
models = {
    'RandomForest': RandomForestClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42, verbose=-1337),
    'XGBoost': XGBClassifier(random_state=42),
    'KNN': KNeighborsClassifier(),
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'GradientBoosting': GradientBoostingClassifier(random_state=42),
    'NaiveBayes': GaussianNB(),
    'SVC': SVC(random_state=42),
    'MLP': MLPClassifier(random_state=42),
    'Baseline': BaselineModel(),
}
# Define the scoring metrics
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='macro'),
    'recall': make_scorer(recall_score, average='macro'),
    'f1': make_scorer(f1_score, average='macro')
}

results = {}
cm = {}
fi = {}

for approach, datasets in approaches.items():
    for dataset in datasets:
        # Load the preprocessed data
        X_train = pd.read_csv(f"./datasets/preprocessed/{approach}/{dataset}/X_train.csv")
        y_train = pd.read_csv(f"./datasets/preprocessed/{approach}/{dataset}/y_train.csv")
        X_test = pd.read_csv(f"./datasets/preprocessed/{approach}/{dataset}/X_test.csv")
        y_test = pd.read_csv(f"./datasets/preprocessed/{approach}/{dataset}/y_test.csv")
        

        # Train the models
        for model_name, model in models.items():
            print(f"Training {model_name} on {approach} - {dataset}...")
            if X_train.shape[0] < 500:
                cv = LeaveOneOut()  # Use LOO for very small datasets
            else:
                # Count samples in smallest class
                class_counts = y_train.value_counts()
                min_class_samples = class_counts.min()
                

                n_splits = min(5, min_class_samples)  # Use at most 5 splits, but no more than samples in smallest class
                cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
            
            cv_type = 'LeaveOneOut' if isinstance(cv, LeaveOneOut) else f'StratifiedKFold with {n_splits} splits'
            cv_results = cross_validate(model, 
                                        X_train, 
                                        y_train.values.ravel(), 
                                        cv=cv, 
                                        scoring=scoring, 
                                        n_jobs=-1, 
                                        verbose=2)
            
            
            # Calculate the mean and standard deviation of the scores
            mean_accuracy = np.mean(cv_results['test_accuracy'])
            std_accuracy = np.std(cv_results['test_accuracy'])
            mean_precision = np.mean(cv_results['test_precision'])
            std_precision = np.std(cv_results['test_precision'])
            mean_recall = np.mean(cv_results['test_recall'])
            std_recall = np.std(cv_results['test_recall'])
            mean_f1 = np.mean(cv_results['test_f1'])
            std_f1 = np.std(cv_results['test_f1'])

            
            # Fit the model on the entire training set
            model.fit(X_train, y_train.values.ravel())
            
            # Make predictions on the test set
            y_pred = model.predict(X_test)
            
            # Calculate the test set metrics
            test_accuracy = accuracy_score(y_test, y_pred)
            test_precision = precision_score(y_test, y_pred, average='macro')
            test_recall = recall_score(y_test, y_pred, average='macro')
            test_f1 = f1_score(y_test, y_pred, average='macro')

            
            results[(approach, dataset, model_name)] = {
                'cv_type': cv_type,	
                'test_accuracy': test_accuracy,
                'test_precision': test_precision,
                'test_recall': test_recall,
                'test_f1': test_f1,
            }
            
            # Store the confusion matrix
            cm[(approach, dataset, model_name)] = pd.crosstab(y_test.values.ravel(), y_pred, rownames=['Actual'], colnames=['Predicted'], margins=True)
            
            # Feature importance
            if hasattr(model, 'feature_importances_'):
                fi[(approach, dataset, model_name)] = pd.DataFrame({
                    'Feature': X_train.columns,
                    'Importance': model.feature_importances_
                }).sort_values(by='Importance', ascending=False)
            elif hasattr(model, 'coef_'):
                fi[(approach, dataset, model_name)] = pd.DataFrame({
                    'Feature': X_train.columns,
                    'Importance': np.abs(model.coef_[0])
                }).sort_values(by='Importance', ascending=False)
            else:
                fi[(approach, dataset, model_name)] = None
# Out:
# Training RandomForest on Initial - real_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# Training LightGBM on Initial - real_data...
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.3s
# [CV] END .................................................... total time=   3.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.9s finished
# Training XGBoost on Initial - real_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# Training KNN on Initial - real_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.0s
# Training DecisionTree on Initial - real_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training GradientBoosting on Initial - real_data...
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.8s finished
# Training NaiveBayes on Initial - real_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training SVC on Initial - real_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.1s
# Training MLP on Initial - real_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training Baseline on Initial - real_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training RandomForest on Initial - synth_data...
# [CV] END .................................................... total time=   0.9s
# [CV] END .................................................... total time=   0.9s
# [CV] END .................................................... total time=   0.9s
# [CV] END .................................................... total time=   0.9s
# [CV] END .................................................... total time=   0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished
# Training LightGBM on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   6.1s
# [CV] END .................................................... total time=   6.1s
# [CV] END .................................................... total time=   6.1s
# [CV] END .................................................... total time=   6.1s
# [CV] END .................................................... total time=   6.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.4s finished
# Training XGBoost on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.8s finished
# Training KNN on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# Training DecisionTree on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training GradientBoosting on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   5.2s
# [CV] END .................................................... total time=   5.2s
# [CV] END .................................................... total time=   5.2s
# [CV] END .................................................... total time=   5.2s
# [CV] END .................................................... total time=   5.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.3s finished
# Training NaiveBayes on Initial - synth_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training SVC on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   4.2s
# [CV] END .................................................... total time=   4.2s
# [CV] END .................................................... total time=   4.2s
# [CV] END .................................................... total time=   4.3s
# [CV] END .................................................... total time=   4.3s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.3s finished
# Training MLP on Initial - synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.8s finished
# [CV] END .................................................... total time=   6.6s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   6.7s
# [CV] END .................................................... total time=   6.8s
# [CV] END .................................................... total time=   6.8s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training Baseline on Initial - synth_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training RandomForest on Extra - real_data...
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.2s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.2s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.3s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.2s
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# ...
# [CV] END .................................................... total time=   0.6s
# [CV] END .................................................... total time=   0.7s
# [CV] END .................................................... total time=   0.7s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training Baseline on Extra - real_pseudoreal_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training RandomForest on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   1.6s
# [CV] END .................................................... total time=   1.6s
# [CV] END .................................................... total time=   1.7s
# [CV] END .................................................... total time=   1.7s
# [CV] END .................................................... total time=   1.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.7s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training LightGBM on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   4.5s
# [CV] END .................................................... total time=   4.5s
# [CV] END .................................................... total time=   4.6s
# [CV] END .................................................... total time=   4.6s
# [CV] END .................................................... total time=   4.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.8s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training XGBoost on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   0.8s
# [CV] END .................................................... total time=   0.8s
# [CV] END .................................................... total time=   0.8s
# [CV] END .................................................... total time=   0.8s
# [CV] END .................................................... total time=   0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training KNN on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.3s
# [CV] END .................................................... total time=   0.4s
# [CV] END .................................................... total time=   0.4s
# Training DecisionTree on Extra - real_pseudoreal_synth_data...
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.1s
# Training GradientBoosting on Extra - real_pseudoreal_synth_data...
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   5.9s
# [CV] END .................................................... total time=   5.9s
# [CV] END .................................................... total time=   5.9s
# [CV] END .................................................... total time=   5.9s
# [CV] END .................................................... total time=   6.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    6.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Training NaiveBayes on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Training SVC on Extra - real_pseudoreal_synth_data...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [CV] END .................................................... total time=   5.6s
# [CV] END .................................................... total time=   5.6s
# [CV] END .................................................... total time=   5.6s
# [CV] END .................................................... total time=   5.7s
# [CV] END .................................................... total time=   5.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    5.7s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# Training MLP on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   7.2s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV] END .................................................... total time=   7.8s
# [CV] END .................................................... total time=   7.8s
# [CV] END .................................................... total time=   7.9s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    8.0s finished
# [CV] END .................................................... total time=   8.0s
# Training Baseline on Extra - real_pseudoreal_synth_data...
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# /home/iven/.pyenv/versions/3.12.9/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# pickle the results
import pickle
with open('untuned-results.pkl', 'wb') as f:
    pickle.dump(results, f)

# Print the results
for (approach, dataset, model_name), metrics in results.items():
    print(f"Results for {model_name} on {approach} - {dataset}:")
    print(f"Cross-validation type: {metrics['cv_type']}")
    print(f"Test Accuracy: {metrics['test_accuracy']:.4f}")
    print(f"Test Precision: {metrics['test_precision']:.4f}")
    print(f"Test Recall: {metrics['test_recall']:.4f}")
    print(f"Test F1 Score: {metrics['test_f1']:.4f}")
    print("-" * 50)
# Out:
# Results for RandomForest on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8365
# Test Precision: 0.8300
# Test Recall: 0.8305
# Test F1 Score: 0.8287
# --------------------------------------------------
# Results for LightGBM on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8510
# Test Precision: 0.8442
# Test Recall: 0.8454
# Test F1 Score: 0.8441
# --------------------------------------------------
# Results for XGBoost on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8317
# Test Precision: 0.8250
# Test Recall: 0.8253
# Test F1 Score: 0.8231
# --------------------------------------------------
# Results for KNN on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7596
# Test Precision: 0.7484
# Test Recall: 0.7501
# Test F1 Score: 0.7355
# --------------------------------------------------
# Results for DecisionTree on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7668
# Test Precision: 0.7592
# Test Recall: 0.7543
# Test F1 Score: 0.7537
# --------------------------------------------------
# Results for GradientBoosting on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7957
# Test Precision: 0.7904
# Test Recall: 0.7914
# Test F1 Score: 0.7886
# --------------------------------------------------
# Results for NaiveBayes on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4255
# Test Precision: 0.5639
# Test Recall: 0.4151
# Test F1 Score: 0.3401
# --------------------------------------------------
# Results for SVC on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7452
# Test Precision: 0.7427
# Test Recall: 0.7379
# Test F1 Score: 0.7313
# --------------------------------------------------
# Results for MLP on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7812
# Test Precision: 0.7697
# Test Recall: 0.7734
# Test F1 Score: 0.7691
# --------------------------------------------------
# Results for Baseline on Initial - real_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.1683
# Test Precision: 0.0240
# Test Recall: 0.1429
# Test F1 Score: 0.0412
# --------------------------------------------------
# Results for RandomForest on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8101
# Test Precision: 0.8029
# Test Recall: 0.8023
# Test F1 Score: 0.7972
# --------------------------------------------------
# Results for LightGBM on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8077
# Test Precision: 0.8041
# Test Recall: 0.8024
# Test F1 Score: 0.8001
# --------------------------------------------------
# Results for XGBoost on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.8077
# Test Precision: 0.8044
# Test Recall: 0.8029
# Test F1 Score: 0.7995
# --------------------------------------------------
# Results for KNN on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7572
# Test Precision: 0.7499
# Test Recall: 0.7506
# Test F1 Score: 0.7407
# --------------------------------------------------
# Results for DecisionTree on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7139
# Test Precision: 0.7007
# Test Recall: 0.7081
# Test F1 Score: 0.7002
# --------------------------------------------------
# Results for GradientBoosting on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7476
# Test Precision: 0.7403
# Test Recall: 0.7413
# Test F1 Score: 0.7350
# --------------------------------------------------
# Results for NaiveBayes on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5000
# Test Precision: 0.5944
# Test Recall: 0.4878
# Test F1 Score: 0.4449
# --------------------------------------------------
# Results for SVC on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7596
# Test Precision: 0.7581
# Test Recall: 0.7517
# Test F1 Score: 0.7473
# --------------------------------------------------
# Results for MLP on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.7524
# Test Precision: 0.7432
# Test Recall: 0.7443
# Test F1 Score: 0.7404
# --------------------------------------------------
# Results for Baseline on Initial - synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.1562
# Test Precision: 0.0223
# Test Recall: 0.1429
# Test F1 Score: 0.0386
# --------------------------------------------------
# Results for RandomForest on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5435
# Test Precision: 0.2278
# Test Recall: 0.1818
# Test F1 Score: 0.1803
# --------------------------------------------------
# Results for LightGBM on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5870
# Test Precision: 0.2923
# Test Recall: 0.2469
# Test F1 Score: 0.2506
# --------------------------------------------------
# Results for XGBoost on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.4457
# Test Precision: 0.1520
# Test Recall: 0.1644
# Test F1 Score: 0.1553
# --------------------------------------------------
# Results for KNN on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5217
# Test Precision: 0.0816
# Test Recall: 0.1319
# Test F1 Score: 0.1008
# --------------------------------------------------
# Results for DecisionTree on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.4022
# Test Precision: 0.1668
# Test Recall: 0.1803
# Test F1 Score: 0.1719
# --------------------------------------------------
# Results for GradientBoosting on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5543
# Test Precision: 0.2380
# Test Recall: 0.2153
# Test F1 Score: 0.2148
# --------------------------------------------------
# Results for NaiveBayes on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.0652
# Test Precision: 0.0818
# Test Recall: 0.1349
# Test F1 Score: 0.0450
# --------------------------------------------------
# Results for SVC on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5652
# Test Precision: 0.0825
# Test Recall: 0.1429
# Test F1 Score: 0.1046
# --------------------------------------------------
# Results for MLP on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5435
# Test Precision: 0.1652
# Test Recall: 0.1607
# Test F1 Score: 0.1480
# --------------------------------------------------
# Results for Baseline on Extra - real_data:
# Cross-validation type: LeaveOneOut
# Test Accuracy: 0.5652
# Test Precision: 0.0807
# Test Recall: 0.1429
# Test F1 Score: 0.1032
# --------------------------------------------------
# Results for RandomForest on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5435
# Test Precision: 0.4610
# Test Recall: 0.4373
# Test F1 Score: 0.4258
# --------------------------------------------------
# Results for LightGBM on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5652
# Test Precision: 0.3496
# Test Recall: 0.3849
# Test F1 Score: 0.3573
# --------------------------------------------------
# Results for XGBoost on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5543
# Test Precision: 0.4086
# Test Recall: 0.4508
# Test F1 Score: 0.4178
# --------------------------------------------------
# Results for KNN on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4239
# Test Precision: 0.3926
# Test Recall: 0.5463
# Test F1 Score: 0.4080
# --------------------------------------------------
# Results for DecisionTree on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4674
# Test Precision: 0.3751
# Test Recall: 0.3583
# Test F1 Score: 0.3537
# --------------------------------------------------
# Results for GradientBoosting on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5435
# Test Precision: 0.3152
# Test Recall: 0.3583
# Test F1 Score: 0.3295
# --------------------------------------------------
# Results for NaiveBayes on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.1848
# Test Precision: 0.2317
# Test Recall: 0.2169
# Test F1 Score: 0.1358
# --------------------------------------------------
# Results for SVC on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4130
# Test Precision: 0.2356
# Test Recall: 0.2713
# Test F1 Score: 0.2396
# --------------------------------------------------
# Results for MLP on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4130
# Test Precision: 0.2219
# Test Recall: 0.2297
# Test F1 Score: 0.2215
# --------------------------------------------------
# Results for Baseline on Extra - real_pseudoreal_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.0978
# Test Precision: 0.0140
# Test Recall: 0.1429
# Test F1 Score: 0.0255
# --------------------------------------------------
# Results for RandomForest on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4457
# Test Precision: 0.3275
# Test Recall: 0.4131
# Test F1 Score: 0.3512
# --------------------------------------------------
# Results for LightGBM on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5000
# Test Precision: 0.3720
# Test Recall: 0.4576
# Test F1 Score: 0.3946
# --------------------------------------------------
# Results for XGBoost on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5217
# Test Precision: 0.3732
# Test Recall: 0.4420
# Test F1 Score: 0.3878
# --------------------------------------------------
# Results for KNN on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4783
# Test Precision: 0.3225
# Test Recall: 0.4068
# Test F1 Score: 0.3394
# --------------------------------------------------
# Results for DecisionTree on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.3913
# Test Precision: 0.2372
# Test Recall: 0.2760
# Test F1 Score: 0.2435
# --------------------------------------------------
# Results for GradientBoosting on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.5217
# Test Precision: 0.3772
# Test Recall: 0.4602
# Test F1 Score: 0.3903
# --------------------------------------------------
# Results for NaiveBayes on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.2500
# Test Precision: 0.2314
# Test Recall: 0.2562
# Test F1 Score: 0.1886
# --------------------------------------------------
# Results for SVC on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4674
# Test Precision: 0.2765
# Test Recall: 0.3129
# Test F1 Score: 0.2836
# --------------------------------------------------
# Results for MLP on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.4674
# Test Precision: 0.2685
# Test Recall: 0.3026
# Test F1 Score: 0.2754
# --------------------------------------------------
# Results for Baseline on Extra - real_pseudoreal_synth_data:
# Cross-validation type: StratifiedKFold with 5 splits
# Test Accuracy: 0.0109
# Test Precision: 0.0016
# Test Recall: 0.1429
# Test F1 Score: 0.0031
# --------------------------------------------------

# %%
# 1) Flatten into a DataFrame
records = []
for (approach, dataset, model), metrics in results.items():
    records.append({
        'approach': approach,
        'dataset': dataset,
        'model': model,
        'f1': metrics['test_f1']
    })
df = pd.DataFrame.from_records(records)

# 2) Define the explicit color map for known datasets
color_map = {
    'real_data': 'green',
    'real_pseudoreal_data': 'red',
    # add other explicit mappings here…
}

# 3) Plotting helper
def plot_approach(df, approach_name):
    sub = df[df['approach'] == approach_name]
    pivot = sub.pivot(index='model', columns='dataset', values='f1')
    
    # Build a colors list, falling back to the default cycle
    default_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
    default_iter = iter(default_cycle)
    colors = [
        color_map.get(ds, next(default_iter))
        for ds in pivot.columns
    ]
    
    ax = pivot.plot(
        kind='bar',
        figsize=(8, 6),
        width=0.8,
        color=colors
    )
    ax.set_title(f'F1 Scores — {approach_name}')
    ax.set_ylabel('Test F1 Score')
    ax.set_xlabel('Model')
    ax.legend(title='Dataset')
    plt.xticks(rotation=60, ha='center')
    plt.tight_layout()
    plt.show()

# 4) Draw both charts
plot_approach(df, 'Initial')
plot_approach(df, 'Extra')
